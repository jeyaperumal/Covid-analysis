# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import folium

# %% [markdown]
# # 1. Import pandas and read in the india_statewise.json file into a dataframe called covid.

# %%
covid=pd.read_json('/Users/sutharsha/Desktop/Courses_and_Internship/NIELIT/datasets/india_statewise.json')
covid
# Out:
#                success                                               data  \
# lastRefreshed     True                           2020-07-12T03:54:15.207Z
# source            True                                   covid19india.org
# statewise         True  [{'state': 'Maharashtra', 'confirmed': 246600,...
# total             True  {'confirmed': 850358, 'recovered': 536231, 'de...
#
#                           lastRefreshed          lastOriginUpdate
# lastRefreshed  2020-07-12T03:54:15.207Z  2020-07-12T03:54:15.207Z
# source         2020-07-12T03:54:15.207Z  2020-07-12T03:54:15.207Z
# statewise      2020-07-12T03:54:15.207Z  2020-07-12T03:54:15.207Z
# total          2020-07-12T03:54:15.207Z  2020-07-12T03:54:15.207Z

# %% [markdown]
# # 2. Normalize the dataframe with ‘data’ as column and ‘statewise’ as row and rename it as df_india

# %%
df_india = pd.io.json.json_normalize(covid['data']['statewise'])

# %%
df_india
# Out:
#     active  confirmed  deaths  recovered  \
# 0    99202     246600   10116     136985
# 1    46413     134226    1898      85915
# 2    19895     110921    3334      87692
# 3    10309      41027    2033      28685
# 4    11490      35092     913      22689
# 5    20879      36216     615      14718
# 6    12135      33402     348      20919
# 7     9588      28453     906      17959
# 8    12533      27235     309      14393
# 9     5376      23748     503      17869
# 10    4891      20582     297      15394
# 11    3878      17201     644      12679
# 12    5605      16072      37      10427
# 13    3930      15039     118      10991
# 14    4087      12526      79       8360
# 15    4092      10156     169       5895
# 16    2352       7587     195       5040
# 17    3442       7439      30       3963
# 18    3416       3416       0          0
# 19     810       3897      17       3070
# 20     623       3417      46       2718
# 21    1383       3663      24       2256
# 22     928       2368      12       1428
# 23     571       1962       2       1375
# 24     750       1593       0        843
# 25     628       1336      18        690
# 26     264       1182      10        895
# 27     148       1077       1        928
# 28     435        748       0        313
# 29     128        549       8        413
# 30     240        482       1        237
# 31     214        341       2        125
# 32      77        227       0        150
# 33      64        156       0         92
# 34      67        160       0         80
# 35     215        262       2         45
# 36       0          0       0          0
#
#                                        state
# 0                                Maharashtra
# 1                                 Tamil Nadu
# 2                                      Delhi
# 3                                    Gujarat
# 4                              Uttar Pradesh
# 5                                  Karnataka
# 6                                  Telangana
# 7                                West Bengal
# 8                             Andhra Pradesh
# 9                                  Rajasthan
# 10                                   Haryana
# 11                            Madhya Pradesh
# 12                                     Assam
# 13                                     Bihar
# 14                                    Odisha
# 15                         Jammu and Kashmir
# 16                                    Punjab
# 17                                    Kerala
# 18                          State Unassigned
# 19                              Chhattisgarh
# 20                               Uttarakhand
# 21                                 Jharkhand
# 22                                       Goa
# 23                                   Tripura
# 24                                   Manipur
# 25                                Puducherry
# 26                          Himachal Pradesh
# 27                                    Ladakh
# 28                                  Nagaland
# 29                                Chandigarh
# 30  Dadra and Nagar Haveli and Daman and Diu
# 31                         Arunachal Pradesh
# 32                                   Mizoram
# 33               Andaman and Nicobar Islands
# 34                                    Sikkim
# 35                                 Meghalaya
# 36                               Lakshadweep

# %% [markdown]
# # 3. Now make ‘state’ column as reset

# %%
df_india = df_india.set_index('state')
df_india
# Out:
#                                           active  confirmed  deaths  recovered
# state
# Maharashtra                                99202     246600   10116     136985
# Tamil Nadu                                 46413     134226    1898      85915
# Delhi                                      19895     110921    3334      87692
# Gujarat                                    10309      41027    2033      28685
# Uttar Pradesh                              11490      35092     913      22689
# Karnataka                                  20879      36216     615      14718
# Telangana                                  12135      33402     348      20919
# West Bengal                                 9588      28453     906      17959
# Andhra Pradesh                             12533      27235     309      14393
# Rajasthan                                   5376      23748     503      17869
# Haryana                                     4891      20582     297      15394
# Madhya Pradesh                              3878      17201     644      12679
# Assam                                       5605      16072      37      10427
# Bihar                                       3930      15039     118      10991
# Odisha                                      4087      12526      79       8360
# Jammu and Kashmir                           4092      10156     169       5895
# Punjab                                      2352       7587     195       5040
# Kerala                                      3442       7439      30       3963
# State Unassigned                            3416       3416       0          0
# Chhattisgarh                                 810       3897      17       3070
# Uttarakhand                                  623       3417      46       2718
# Jharkhand                                   1383       3663      24       2256
# Goa                                          928       2368      12       1428
# Tripura                                      571       1962       2       1375
# Manipur                                      750       1593       0        843
# Puducherry                                   628       1336      18        690
# Himachal Pradesh                             264       1182      10        895
# Ladakh                                       148       1077       1        928
# Nagaland                                     435        748       0        313
# Chandigarh                                   128        549       8        413
# Dadra and Nagar Haveli and Daman and Diu     240        482       1        237
# Arunachal Pradesh                            214        341       2        125
# Mizoram                                       77        227       0        150
# Andaman and Nicobar Islands                   64        156       0         92
# Sikkim                                        67        160       0         80
# Meghalaya                                    215        262       2         45
# Lakshadweep                                    0          0       0          0

# %% [markdown]
# # 4. Now Identify a row which is not a valid state and drop it

# %%
 df_india.drop(["State Unassigned"], inplace = True)

# %%
df_india
# Out:
#                                           active  confirmed  deaths  recovered
# state
# Maharashtra                                99202     246600   10116     136985
# Tamil Nadu                                 46413     134226    1898      85915
# Delhi                                      19895     110921    3334      87692
# Gujarat                                    10309      41027    2033      28685
# Uttar Pradesh                              11490      35092     913      22689
# Karnataka                                  20879      36216     615      14718
# Telangana                                  12135      33402     348      20919
# West Bengal                                 9588      28453     906      17959
# Andhra Pradesh                             12533      27235     309      14393
# Rajasthan                                   5376      23748     503      17869
# Haryana                                     4891      20582     297      15394
# Madhya Pradesh                              3878      17201     644      12679
# Assam                                       5605      16072      37      10427
# Bihar                                       3930      15039     118      10991
# Odisha                                      4087      12526      79       8360
# Jammu and Kashmir                           4092      10156     169       5895
# Punjab                                      2352       7587     195       5040
# Kerala                                      3442       7439      30       3963
# Chhattisgarh                                 810       3897      17       3070
# Uttarakhand                                  623       3417      46       2718
# Jharkhand                                   1383       3663      24       2256
# Goa                                          928       2368      12       1428
# Tripura                                      571       1962       2       1375
# Manipur                                      750       1593       0        843
# Puducherry                                   628       1336      18        690
# Himachal Pradesh                             264       1182      10        895
# Ladakh                                       148       1077       1        928
# Nagaland                                     435        748       0        313
# Chandigarh                                   128        549       8        413
# Dadra and Nagar Haveli and Daman and Diu     240        482       1        237
# Arunachal Pradesh                            214        341       2        125
# Mizoram                                       77        227       0        150
# Andaman and Nicobar Islands                   64        156       0         92
# Sikkim                                        67        160       0         80
# Meghalaya                                    215        262       2         45
# Lakshadweep                                    0          0       0          0

# %% [markdown]
# # 5. Calculate the Mortality rate (deaths/confirmed) for each state and identify top 5 sates with highest mortality rate.

# %%
df_india['mortality rate'] = df_india['deaths'] / df_india['confirmed']

# %%
df_india.head()
# Out:
#                active  confirmed  deaths  recovered  mortality rate
# state
# Maharashtra     99202     246600   10116     136985        0.041022
# Tamil Nadu      46413     134226    1898      85915        0.014140
# Delhi           19895     110921    3334      87692        0.030057
# Gujarat         10309      41027    2033      28685        0.049553
# Uttar Pradesh   11490      35092     913      22689        0.026017

# %% [markdown]
# # 6. Now add the latitude and longitude information of each state in the df_india dataframe
#
# using the dictionary dataset (named locations) given below:
# locations = {
# "Kerala" : [10.8505,76.2711], "Maharashtra" : [19.7515,75.7139], "Karnataka": [15.3173,75.7139], "Telangana": [18.1124,79.0193], "Uttar Pradesh": [26.8467,80.9462], "Rajasthan": [27.0238,74.2179], "Gujarat":[22.2587,71.1924], "Delhi" : [28.7041,77.1025], "Punjab":[31.1471,75.3412],
# "Tamil Nadu": [11.1271,78.6569], "Haryana": [29.0588,76.0856],
# "Madhya Pradesh":[22.9734,78.6569], "Jammu and Kashmir":[33.7782,76.5762], "Ladakh": [34.1526,77.5770],
# "Andhra Pradesh":[15.9129,79.7400],
# "West Bengal": [22.9868,87.8550],
# "Bihar": [25.0961,85.3131], "Chhattisgarh":[21.2787,81.8661], "Chandigarh":[30.7333,76.7794], "Uttarakhand":[30.0668,79.0193],
# "Himachal Pradesh":[31.1048,77.1734],
# "Goa": [15.2993,74.1240], "Odisha":[20.9517,85.0985],
# "Andaman and Nicobar Islands": [11.7401,92.6586], "Puducherry":[11.9416,79.8083], "Manipur":[24.6637,93.9063], "Mizoram":[23.1645,92.9376],
#
# "Assam":[26.2006,92.9376], "Meghalaya":[25.4670,91.3662], "Tripura":[23.9408,91.9882], "Arunachal Pradesh":[28.2180,94.7278], "Jharkhand" : [23.6102,85.2799], "Nagaland": [26.1584,94.5624], "Sikkim": [27.5330,88.5122],
# "Dadra and Nagar Haveli and Daman and Diu":[20.1809,73.0169],
# "Lakshadweep":[10.5667,72.6417], }

# %%
locations = {
    "Kerala" : [10.8505,76.2711],
    "Maharashtra" : [19.7515,75.7139],
    "Karnataka": [15.3173,75.7139],
    "Telangana": [18.1124,79.0193],
    "Uttar Pradesh": [26.8467,80.9462],
    "Rajasthan": [27.0238,74.2179],
    "Gujarat":[22.2587,71.1924],
    "Delhi" : [28.7041,77.1025],
    "Punjab":[31.1471,75.3412],
    "Tamil Nadu": [11.1271,78.6569],
    "Haryana": [29.0588,76.0856],
    "Madhya Pradesh":[22.9734,78.6569],
    "Jammu and Kashmir":[33.7782,76.5762],
    "Ladakh": [34.1526,77.5770],
    "Andhra Pradesh":[15.9129,79.7400],
    "West Bengal": [22.9868,87.8550],
    "Bihar": [25.0961,85.3131],
    "Chhattisgarh":[21.2787,81.8661],
    "Chandigarh":[30.7333,76.7794],
    "Uttarakhand":[30.0668,79.0193],
    "Himachal Pradesh":[31.1048,77.1734],
    "Goa": [15.2993,74.1240],
    "Odisha":[20.9517,85.0985],
    "Andaman and Nicobar Islands": [11.7401,92.6586],
    "Puducherry":[11.9416,79.8083],
    "Manipur":[24.6637,93.9063],
    "Mizoram":[23.1645,92.9376],
    "Assam":[26.2006,92.9376],
    "Meghalaya":[25.4670,91.3662],
    "Tripura":[23.9408,91.9882],
    "Arunachal Pradesh":[28.2180,94.7278],
    "Jharkhand" : [23.6102,85.2799],
    "Nagaland": [26.1584,94.5624],
    "Sikkim": [27.5330,88.5122],
    "Dadra and Nagar Haveli and Daman and Diu":[20.1809,73.0169],
    "Lakshadweep":[10.5667,72.6417],
}

# %%
df_india['Lat'] = ""
df_india['Long'] = ""
for index in df_india.index:
    df_india.loc[df_india.index==index,'Lat'] = locations[index][0]
    df_india.loc[df_india.index==index,'Long'] = locations[index][1]

# %%
df_india.head()
# Out:
#                active  confirmed  deaths  recovered  mortality rate      Lat  \
# state
# Maharashtra     99202     246600   10116     136985        0.041022  19.7515
# Tamil Nadu      46413     134226    1898      85915        0.014140  11.1271
# Delhi           19895     110921    3334      87692        0.030057  28.7041
# Gujarat         10309      41027    2033      28685        0.049553  22.2587
# Uttar Pradesh   11490      35092     913      22689        0.026017  26.8467
#
#                   Long
# state
# Maharashtra    75.7139
# Tamil Nadu     78.6569
# Delhi          77.1025
# Gujarat        71.1924
# Uttar Pradesh  80.9462

# %% [markdown]
# # 6. Now plot this data using folium map

# %%
india_map = folium.Map(location=[23,80],tiles='cartodbpositron',zoom_start=4,max_zoom=7,min_zoom=4,height=500,width='80%')

# %%
for i in range(0,len(df_india[df_india['confirmed']>0].index)):
    folium.Circle(
        location=[df_india.iloc[i]['Lat'],df_india.iloc[i]['Long']],
        tooltip = "<h5>"+df_india.iloc[i].name+"</h5>"+
        "<li>Confirmed:"+str(df_india.iloc[i]['confirmed'])+"</li>"+
        "<li>Recovered:"+str(df_india.iloc[i]['recovered'])+"</li>"+
        "<li>Active:"+str(df_india.iloc[i]['active'])+"</li>"+
        "<li>Deaths:"+str(df_india.iloc[i]['deaths'])+"</li>"+
        "<li>Mortality Rate:"+str(df_india.iloc[i]['mortality rate'])+"</li>",
        
        radius = (int((df_india.iloc[i]['confirmed']))*0.5),
        color = '#ff6600',
        fill_color = '#ff6600',
        fill=True).add_to(india_map)
india_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
